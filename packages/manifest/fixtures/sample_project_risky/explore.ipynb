# %%
# !pip install torch==2.3.0 datasets

# %% [markdown]
# # Demo notebook

# %%
from transformers import AutoModel

model = AutoModel.from_pretrained("google/flan-t5-small")
ds = load_dataset("imdb")
